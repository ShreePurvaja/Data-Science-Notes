# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreePurvaja/Data-Science-Notes/blob/main/RNN%2CLSTM%2CTranformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 22-04-2025

# %%
# !pip uninstall torchtext
# !pip install torchtext==0.17.1
# Out:
# WARNING: Skipping torchtext as it is not installed.
# Collecting torchtext==0.17.1
#   Downloading torchtext-0.17.1-cp311-cp311-manylinux1_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torchtext==0.17.1) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchtext==0.17.1) (2.32.3)
# Collecting torch==2.2.1 (from torchtext==0.17.1)
#   Downloading torch-2.2.1-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchtext==0.17.1) (2.0.2)
# Collecting torchdata==0.7.1 (from torchtext==0.17.1)
#   Downloading torchdata-0.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1->torchtext==0.17.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1->torchtext==0.17.1) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1->torchtext==0.17.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1->torchtext==0.17.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1->torchtext==0.17.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.2.1->torchtext==0.17.1) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch==2.2.1->torchtext==0.17.1)
#   Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.11/dist-packages (from torchdata==0.7.1->torchtext==0.17.1) (2.4.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1->torchtext==0.17.1) (12.5.82)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.17.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.17.1) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.17.1) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.2.1->torchtext==0.17.1) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.2.1->torchtext==0.17.1) (1.3.0)
# Downloading torchtext-0.17.1-cp311-cp311-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 72.2 MB/s eta 0:00:00
# Downloading torch-2.2.1-cp311-cp311-manylinux1_x86_64.whl (755.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 947.6 kB/s eta 0:00:00
# Downloading torchdata-0.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 89.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 74.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 63.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 36.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.4 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/86/94/eb540db023ce1d162e7bea9f8f5aa781d57c65aed513c33ee9a5123ead4d/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.1 MB/s eta 0:00:00
# Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 6.2 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, torchdata, torchtext
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.2.1 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.2.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvtx-cu12-12.1.105 torch-2.2.1 torchdata-0.7.1 torchtext-0.17.1 triton-2.2.0

# %%
import torch
from torchtext.data.utils import get_tokenizer
from collections import Counter
from torchtext.vocab import build_vocab_from_iterator


# Sample text data
text = """Nethaji Nirmal is a well-known educator and data science expert associated with GUVI, an online learning platform that focuses on upskilling students in areas like programming, data science, and full stack development. At GUVI, he plays a key role in conducting webinars, live classes, and project-based sessions for learners pursuing Python programming, data extraction, machine learning, and big data technologies.
  Nirmal is appreciated for his hands-on teaching approach,
  making complex concepts easier through real-time coding
  demonstrations and practical examples. He regularly conducts sessions on topics like
 “Introduction to Python,” “Data Extraction using Python,” and “Big Data Essentials,”
  helping learners understand the industry applications of these technologies.
  His workshops often cover real-world scenarios such as using APIs, handling large
   datasets, automating tasks, and deploying applications.
  Beyond his work at GUVI, Nirmal is also a contributor on
  GitHub and Hugging Face, where he shares projects related to
 data analytics, Twitter scraping, machine learning models,
 and deployment using tools like Docker. As the co-founder of Webdojo,
 he promotes project-based learning and industry readiness among students.
 Nethaji Nirmal’s passion for teaching, combined with his technical expertise,
 has made him a respected figure in the Indian edtech community,
  especially among those aspiring to enter the field of data science."""


# Tokenize the text
tokenizer = get_tokenizer('basic_english')
tokens = tokenizer(text.lower())


# Build the vocabulary
counter = Counter(tokens)
vocab = build_vocab_from_iterator([tokens], specials=['<unk>', '<pad>'])
vocab.set_default_index(vocab['<unk>'])


# Numericalize the text
data = [vocab[token] for token in tokens]


# Convert data to tensors and create batches
seq_length = 30
def create_batches(data, seq_length):
   sequences = [data[i:i+seq_length] for i in range(0, len(data)-seq_length)]
   inputs = torch.tensor([seq[:-1] for seq in sequences], dtype=torch.long)
   targets = torch.tensor([seq[-1] for seq in sequences], dtype=torch.long)
   return inputs, targets


inputs, targets = create_batches(data, seq_length)
train_data, val_data = inputs[:int(0.8*len(inputs))], inputs[int(0.8*len(inputs)):]
train_targets, val_targets = targets[:int(0.8*len(targets))], targets[int(0.8*len(targets)):]


# DataLoader
train_dataset = torch.utils.data.TensorDataset(train_data, train_targets)
val_dataset = torch.utils.data.TensorDataset(val_data, val_targets)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=20, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=20)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#RNN model
import torch.nn as nn
import torch.optim as optim


class RNNModel(nn.Module):
   def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
       super(RNNModel, self).__init__()
       self.embedding = nn.Embedding(vocab_size, embedding_dim)
       self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True)
       self.fc = nn.Linear(hidden_dim, output_dim)


   def forward(self, x):
       embedded = self.embedding(x)
       output, hidden = self.rnn(embedded)
       output = self.fc(output[:, -1, :])
       return output


# Initialize the model, criterion, and optimizer
vocab_size = len(vocab)
embedding_dim = 100
hidden_dim = 100
output_dim = vocab_size


model = RNNModel(vocab_size, embedding_dim, hidden_dim, output_dim).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %%
# LSTM instead of RNN

class LSTMModel(nn.Module):
   def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
       super(LSTMModel, self).__init__()
       self.embedding = nn.Embedding(vocab_size, embedding_dim)
       self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
       self.fc = nn.Linear(hidden_dim, output_dim)


   def forward(self, x):
       embedded = self.embedding(x)
       output, (hidden, cell) = self.lstm(embedded)
       output = self.fc(output[:, -1, :])
       return output


# Initialize the LSTM model
model = LSTMModel(vocab_size, embedding_dim, hidden_dim, output_dim).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())


# # Train the LSTM model
# for epoch in range(1, 201):
#    train_loss = train_epoch(train_loader, model, criterion, optimizer)
#    val_loss = evaluate(val_loader, model, criterion)
#    print(f'Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

# %%
# tranformer model

import torch.nn as nn
import torch.optim as optim
import math


class PositionalEncoding(nn.Module):
   def __init__(self, d_model, dropout=0.1, max_len=5000):
       super(PositionalEncoding, self).__init__()
       self.dropout = nn.Dropout(p=dropout)
       pe = torch.zeros(max_len, d_model)
       position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
       div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
       pe[:, 0::2] = torch.sin(position * div_term)
       pe[:, 1::2] = torch.cos(position * div_term)
       pe = pe.unsqueeze(0).transpose(0, 1)
       self.register_buffer('pe', pe)


   def forward(self, x):
       x = x + self.pe[:x.size(0), :]
       return self.dropout(x)


class TransformerModel(nn.Module):
   def __init__(self, vocab_size, embedding_dim, nhead, num_encoder_layers, hidden_dim, output_dim):
       super(TransformerModel, self).__init__()
       self.embedding = nn.Embedding(vocab_size, embedding_dim)
       self.pos_encoder = PositionalEncoding(embedding_dim)
       encoder_layers = nn.TransformerEncoderLayer(embedding_dim, nhead, hidden_dim)
       self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_encoder_layers)
       self.fc = nn.Linear(embedding_dim, output_dim)


   def forward(self, x):
       embedded = self.embedding(x) * math.sqrt(embedding_dim)
       embedded = self.pos_encoder(embedded)
       output = self.transformer_encoder(embedded)
       output = self.fc(output[:, -1, :])
       return output


# Initialize the model, criterion, and optimizer
vocab_size = len(vocab)
embedding_dim = 200
nhead = 2
num_encoder_layers = 2
hidden_dim = 200
output_dim = vocab_size


model = TransformerModel(vocab_size, embedding_dim, nhead, num_encoder_layers, hidden_dim, output_dim).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
#training and evaluation
def train_epoch(loader, model, criterion, optimizer):
   model.train()
   total_loss = 0
   for inputs, targets in loader:
       inputs, targets = inputs.to(device), targets.to(device)
       optimizer.zero_grad()
       output = model(inputs)
       loss = criterion(output, targets)
       loss.backward()
       optimizer.step()
       total_loss += loss.item()
   return total_loss / len(loader)


def evaluate(loader, model, criterion):
   model.eval()
   total_loss = 0
   with torch.no_grad():
       for inputs, targets in loader:
           inputs, targets = inputs.to(device), targets.to(device)
           output = model(inputs)
           loss = criterion(output, targets)
           total_loss += loss.item()
   return total_loss / len(loader)


for epoch in range(1, 500):
   train_loss = train_epoch(train_loader, model, criterion, optimizer)
   val_loss = evaluate(val_loader, model, criterion)
   print(f'Epoch {epoch}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')
# Out:
# Epoch 1, Train Loss: 4.9682, Val Loss: 5.0286
# Epoch 2, Train Loss: 4.0726, Val Loss: 5.0118
# Epoch 3, Train Loss: 3.5331, Val Loss: 4.9265
# Epoch 4, Train Loss: 2.9801, Val Loss: 4.9444
# Epoch 5, Train Loss: 2.6245, Val Loss: 4.8710
# Epoch 6, Train Loss: 2.1849, Val Loss: 4.9939
# Epoch 7, Train Loss: 1.7988, Val Loss: 5.1052
# Epoch 8, Train Loss: 1.5833, Val Loss: 5.0434
# Epoch 9, Train Loss: 1.3294, Val Loss: 5.2427
# Epoch 10, Train Loss: 1.2804, Val Loss: 5.3303
# Epoch 11, Train Loss: 1.1499, Val Loss: 5.4585
# Epoch 12, Train Loss: 1.1375, Val Loss: 5.5557
# Epoch 13, Train Loss: 0.9908, Val Loss: 5.5913
# Epoch 14, Train Loss: 1.0490, Val Loss: 5.8997
# Epoch 15, Train Loss: 0.8612, Val Loss: 5.9574
# Epoch 16, Train Loss: 0.9393, Val Loss: 5.9901
# Epoch 17, Train Loss: 0.9177, Val Loss: 6.0223
# Epoch 18, Train Loss: 0.9318, Val Loss: 6.1076
# Epoch 19, Train Loss: 0.9099, Val Loss: 6.1578
# Epoch 20, Train Loss: 0.9193, Val Loss: 6.1243
# Epoch 21, Train Loss: 0.8877, Val Loss: 6.1860
# Epoch 22, Train Loss: 0.9141, Val Loss: 6.1892
# Epoch 23, Train Loss: 0.8592, Val Loss: 6.1800
# Epoch 24, Train Loss: 0.8935, Val Loss: 6.3180
# Epoch 25, Train Loss: 0.8083, Val Loss: 6.3188
# Epoch 26, Train Loss: 0.8795, Val Loss: 6.3132
# Epoch 27, Train Loss: 0.8887, Val Loss: 6.3921
# Epoch 28, Train Loss: 0.8624, Val Loss: 6.4130
# Epoch 29, Train Loss: 0.9068, Val Loss: 6.4796
# Epoch 30, Train Loss: 0.8814, Val Loss: 6.5119
# Epoch 31, Train Loss: 0.9330, Val Loss: 6.5807
# Epoch 32, Train Loss: 0.8716, Val Loss: 6.5821
# Epoch 33, Train Loss: 0.8456, Val Loss: 6.6331
# Epoch 34, Train Loss: 0.8720, Val Loss: 6.6464
# Epoch 35, Train Loss: 0.8569, Val Loss: 6.8547
# Epoch 36, Train Loss: 0.9308, Val Loss: 6.7700
# Epoch 37, Train Loss: 0.9188, Val Loss: 6.6618
# Epoch 38, Train Loss: 0.8673, Val Loss: 6.6390
# Epoch 39, Train Loss: 0.8187, Val Loss: 6.6425
# Epoch 40, Train Loss: 0.8715, Val Loss: 6.6235
# Epoch 41, Train Loss: 0.8502, Val Loss: 6.6375
# Epoch 42, Train Loss: 0.8445, Val Loss: 6.7754
# Epoch 43, Train Loss: 0.8126, Val Loss: 6.7609
# Epoch 44, Train Loss: 0.8905, Val Loss: 6.7819
# Epoch 45, Train Loss: 0.8100, Val Loss: 6.6920
# Epoch 46, Train Loss: 0.8393, Val Loss: 6.7224
# Epoch 47, Train Loss: 0.8060, Val Loss: 6.7495
# Epoch 48, Train Loss: 0.7688, Val Loss: 6.8330
# Epoch 49, Train Loss: 0.8412, Val Loss: 6.8357
# Epoch 50, Train Loss: 0.8554, Val Loss: 6.8388
# Epoch 51, Train Loss: 0.7828, Val Loss: 6.8306
# Epoch 52, Train Loss: 0.8414, Val Loss: 6.8821
# Epoch 53, Train Loss: 0.8369, Val Loss: 6.8611
# Epoch 54, Train Loss: 0.8119, Val Loss: 6.9508
# Epoch 55, Train Loss: 0.7744, Val Loss: 7.0581
# Epoch 56, Train Loss: 0.8017, Val Loss: 7.0972
# Epoch 57, Train Loss: 0.8514, Val Loss: 7.0670
# Epoch 58, Train Loss: 0.8610, Val Loss: 7.1192
# Epoch 59, Train Loss: 0.7807, Val Loss: 7.1379
# Epoch 60, Train Loss: 0.8369, Val Loss: 7.0486
# Epoch 61, Train Loss: 0.8422, Val Loss: 7.0211
# Epoch 62, Train Loss: 0.7796, Val Loss: 7.0570
# Epoch 63, Train Loss: 0.7790, Val Loss: 7.0657
# Epoch 64, Train Loss: 0.7214, Val Loss: 7.0566
# Epoch 65, Train Loss: 0.7954, Val Loss: 7.1762
# Epoch 66, Train Loss: 0.7376, Val Loss: 7.1470
# Epoch 67, Train Loss: 0.8421, Val Loss: 7.1151
# Epoch 68, Train Loss: 0.7940, Val Loss: 7.1135
# Epoch 69, Train Loss: 0.7565, Val Loss: 7.1613
# Epoch 70, Train Loss: 0.8070, Val Loss: 7.2636
# Epoch 71, Train Loss: 0.8239, Val Loss: 7.3510
# Epoch 72, Train Loss: 0.8228, Val Loss: 7.3439
# Epoch 73, Train Loss: 0.8110, Val Loss: 7.2661
# Epoch 74, Train Loss: 0.8391, Val Loss: 7.3185
# Epoch 75, Train Loss: 0.8110, Val Loss: 7.4029
# Epoch 76, Train Loss: 0.8061, Val Loss: 7.3951
# Epoch 77, Train Loss: 0.7611, Val Loss: 7.3136
# Epoch 78, Train Loss: 0.8345, Val Loss: 7.3226
# Epoch 79, Train Loss: 0.8370, Val Loss: 7.3049
# Epoch 80, Train Loss: 0.8286, Val Loss: 7.3936
# Epoch 81, Train Loss: 0.8882, Val Loss: 7.3693
# Epoch 82, Train Loss: 0.7957, Val Loss: 7.3403
# Epoch 83, Train Loss: 0.8713, Val Loss: 7.4129
# Epoch 84, Train Loss: 0.8550, Val Loss: 7.4239
# Epoch 85, Train Loss: 0.8180, Val Loss: 7.4473
# Epoch 86, Train Loss: 0.8113, Val Loss: 7.3768
# Epoch 87, Train Loss: 0.7843, Val Loss: 7.4264
# Epoch 88, Train Loss: 0.7854, Val Loss: 7.3383
# Epoch 89, Train Loss: 0.8414, Val Loss: 7.3467
# Epoch 90, Train Loss: 0.7360, Val Loss: 7.3862
# Epoch 91, Train Loss: 0.7652, Val Loss: 7.3914
# Epoch 92, Train Loss: 0.7998, Val Loss: 7.2475
# Epoch 93, Train Loss: 0.8743, Val Loss: 7.2917
# Epoch 94, Train Loss: 0.8072, Val Loss: 7.3656
# Epoch 95, Train Loss: 0.7722, Val Loss: 7.4400
# Epoch 96, Train Loss: 0.8076, Val Loss: 7.3528
# Epoch 97, Train Loss: 0.7900, Val Loss: 7.4197
# Epoch 98, Train Loss: 0.8052, Val Loss: 7.5045
# Epoch 99, Train Loss: 0.8120, Val Loss: 7.6233
# Epoch 100, Train Loss: 0.7928, Val Loss: 7.6138
# Epoch 101, Train Loss: 0.8060, Val Loss: 7.6630
# Epoch 102, Train Loss: 0.7943, Val Loss: 7.6364
# Epoch 103, Train Loss: 0.7945, Val Loss: 7.5793
# Epoch 104, Train Loss: 0.8222, Val Loss: 7.5924
# Epoch 105, Train Loss: 0.8077, Val Loss: 7.6106
# Epoch 106, Train Loss: 0.7795, Val Loss: 7.6677
# Epoch 107, Train Loss: 0.8278, Val Loss: 7.6043
# Epoch 108, Train Loss: 0.7739, Val Loss: 7.6430
# Epoch 109, Train Loss: 0.7889, Val Loss: 7.4211
# Epoch 110, Train Loss: 0.8180, Val Loss: 7.4511
# Epoch 111, Train Loss: 0.8146, Val Loss: 7.6920
# Epoch 112, Train Loss: 0.8552, Val Loss: 7.6884
# Epoch 113, Train Loss: 0.7949, Val Loss: 7.4894
# Epoch 114, Train Loss: 0.7455, Val Loss: 7.4682
# Epoch 115, Train Loss: 0.8401, Val Loss: 7.4191
# Epoch 116, Train Loss: 0.8078, Val Loss: 7.3912
# Epoch 117, Train Loss: 0.7553, Val Loss: 7.4981
# Epoch 118, Train Loss: 0.7934, Val Loss: 7.5078
# Epoch 119, Train Loss: 0.7955, Val Loss: 7.5349
# Epoch 120, Train Loss: 0.8644, Val Loss: 7.5125
# Epoch 121, Train Loss: 0.8133, Val Loss: 7.4968
# Epoch 122, Train Loss: 0.8111, Val Loss: 7.6981
# Epoch 123, Train Loss: 0.7739, Val Loss: 7.6906
# Epoch 124, Train Loss: 0.7311, Val Loss: 7.6755
# Epoch 125, Train Loss: 0.8100, Val Loss: 7.7669
# Epoch 126, Train Loss: 0.7865, Val Loss: 7.8281
# Epoch 127, Train Loss: 0.7671, Val Loss: 7.7136
# Epoch 128, Train Loss: 0.8424, Val Loss: 7.6695
# Epoch 129, Train Loss: 0.7551, Val Loss: 7.6612
# Epoch 130, Train Loss: 0.7951, Val Loss: 7.6974
# Epoch 131, Train Loss: 0.7976, Val Loss: 7.7418
# Epoch 132, Train Loss: 0.7623, Val Loss: 7.8607
# Epoch 133, Train Loss: 0.7892, Val Loss: 7.8183
# Epoch 134, Train Loss: 0.7733, Val Loss: 7.7935
# Epoch 135, Train Loss: 0.8087, Val Loss: 7.9666
# Epoch 136, Train Loss: 0.7490, Val Loss: 7.9148
# Epoch 137, Train Loss: 0.8033, Val Loss: 7.9355
# Epoch 138, Train Loss: 0.7515, Val Loss: 7.9218
# Epoch 139, Train Loss: 0.8072, Val Loss: 7.9745
# Epoch 140, Train Loss: 0.7215, Val Loss: 7.8555
# Epoch 141, Train Loss: 0.8137, Val Loss: 7.8233
# Epoch 142, Train Loss: 0.8052, Val Loss: 7.7787
# Epoch 143, Train Loss: 0.8215, Val Loss: 7.8611
# Epoch 144, Train Loss: 0.8271, Val Loss: 7.8633
# Epoch 145, Train Loss: 0.7970, Val Loss: 7.7919
# Epoch 146, Train Loss: 0.7771, Val Loss: 7.9581
# Epoch 147, Train Loss: 0.7733, Val Loss: 7.9798
# Epoch 148, Train Loss: 0.8070, Val Loss: 7.9347
# Epoch 149, Train Loss: 0.8183, Val Loss: 7.8535
# Epoch 150, Train Loss: 0.8098, Val Loss: 7.7574
# Epoch 151, Train Loss: 0.8015, Val Loss: 7.8698
# Epoch 152, Train Loss: 0.7720, Val Loss: 7.9078
# Epoch 153, Train Loss: 0.8164, Val Loss: 7.8091
# Epoch 154, Train Loss: 0.7937, Val Loss: 7.8131
# Epoch 155, Train Loss: 0.7894, Val Loss: 7.8323
# Epoch 156, Train Loss: 0.7568, Val Loss: 7.8259
# Epoch 157, Train Loss: 0.8135, Val Loss: 7.8304
# Epoch 158, Train Loss: 0.7708, Val Loss: 7.8917
# Epoch 159, Train Loss: 0.7559, Val Loss: 7.9699
# Epoch 160, Train Loss: 0.8031, Val Loss: 7.9767
# Epoch 161, Train Loss: 0.7653, Val Loss: 8.0066
# Epoch 162, Train Loss: 0.7803, Val Loss: 7.9660
# Epoch 163, Train Loss: 0.7933, Val Loss: 7.9553
# Epoch 164, Train Loss: 0.7770, Val Loss: 8.0503
# Epoch 165, Train Loss: 0.7911, Val Loss: 8.0008
# Epoch 166, Train Loss: 0.7928, Val Loss: 8.0959
# Epoch 167, Train Loss: 0.8272, Val Loss: 8.0926
# Epoch 168, Train Loss: 0.7858, Val Loss: 7.9931
# Epoch 169, Train Loss: 0.7919, Val Loss: 7.8996
# Epoch 170, Train Loss: 0.7932, Val Loss: 7.8829
# Epoch 171, Train Loss: 0.8090, Val Loss: 7.8500
# Epoch 172, Train Loss: 0.7655, Val Loss: 7.9174
# Epoch 173, Train Loss: 0.7654, Val Loss: 7.9594
# Epoch 174, Train Loss: 0.7462, Val Loss: 7.9628
# Epoch 175, Train Loss: 0.7548, Val Loss: 8.0337
# Epoch 176, Train Loss: 0.8137, Val Loss: 7.9929
# Epoch 177, Train Loss: 0.8022, Val Loss: 7.9577
# Epoch 178, Train Loss: 0.7941, Val Loss: 8.0369
# Epoch 179, Train Loss: 0.7426, Val Loss: 8.0188
# Epoch 180, Train Loss: 0.8034, Val Loss: 8.1542
# Epoch 181, Train Loss: 0.7970, Val Loss: 8.1839
# Epoch 182, Train Loss: 0.7736, Val Loss: 8.0980
# Epoch 183, Train Loss: 0.7623, Val Loss: 8.1964
# Epoch 184, Train Loss: 0.7716, Val Loss: 8.3151
# Epoch 185, Train Loss: 0.7436, Val Loss: 8.4475
# Epoch 186, Train Loss: 0.7747, Val Loss: 8.5100
# Epoch 187, Train Loss: 0.7964, Val Loss: 8.4329
# Epoch 188, Train Loss: 0.7919, Val Loss: 8.3420
# Epoch 189, Train Loss: 0.7650, Val Loss: 8.4311
# Epoch 190, Train Loss: 0.7530, Val Loss: 8.4302
# Epoch 191, Train Loss: 0.7503, Val Loss: 8.3704
# Epoch 192, Train Loss: 0.7801, Val Loss: 8.3887
# Epoch 193, Train Loss: 0.8278, Val Loss: 8.4232
# Epoch 194, Train Loss: 0.7954, Val Loss: 8.3537
# Epoch 195, Train Loss: 0.7486, Val Loss: 8.4277
# Epoch 196, Train Loss: 0.8354, Val Loss: 8.4784
# Epoch 197, Train Loss: 0.7333, Val Loss: 8.5167
# Epoch 198, Train Loss: 0.7810, Val Loss: 8.4588
# Epoch 199, Train Loss: 0.7790, Val Loss: 8.3833
# Epoch 200, Train Loss: 0.8015, Val Loss: 8.3827
# Epoch 201, Train Loss: 0.8114, Val Loss: 8.3563
# Epoch 202, Train Loss: 0.8166, Val Loss: 8.2986
# Epoch 203, Train Loss: 0.7839, Val Loss: 8.2753
# Epoch 204, Train Loss: 0.7781, Val Loss: 8.4341
# Epoch 205, Train Loss: 0.7027, Val Loss: 8.3707
# Epoch 206, Train Loss: 0.7751, Val Loss: 8.3511
# Epoch 207, Train Loss: 0.7920, Val Loss: 8.4535
# Epoch 208, Train Loss: 0.8402, Val Loss: 8.5566
# Epoch 209, Train Loss: 0.7664, Val Loss: 8.5847
# Epoch 210, Train Loss: 0.7839, Val Loss: 8.4171
# Epoch 211, Train Loss: 0.7389, Val Loss: 8.3519
# Epoch 212, Train Loss: 0.7929, Val Loss: 8.3668
# Epoch 213, Train Loss: 0.7541, Val Loss: 8.4837
# Epoch 214, Train Loss: 0.8166, Val Loss: 8.4562
# Epoch 215, Train Loss: 0.7838, Val Loss: 8.4500
# Epoch 216, Train Loss: 0.7720, Val Loss: 8.4750
# Epoch 217, Train Loss: 0.7928, Val Loss: 8.3515
# Epoch 218, Train Loss: 0.7549, Val Loss: 8.3959
# Epoch 219, Train Loss: 0.7942, Val Loss: 8.4257
# Epoch 220, Train Loss: 0.7704, Val Loss: 8.4438
# Epoch 221, Train Loss: 0.7587, Val Loss: 8.4447
# Epoch 222, Train Loss: 0.7277, Val Loss: 8.4043
# Epoch 223, Train Loss: 0.7969, Val Loss: 8.3629
# Epoch 224, Train Loss: 0.8398, Val Loss: 8.4547
# Epoch 225, Train Loss: 0.7930, Val Loss: 8.4910
# Epoch 226, Train Loss: 0.8122, Val Loss: 8.4762
# Epoch 227, Train Loss: 0.8349, Val Loss: 8.5246
# Epoch 228, Train Loss: 0.7546, Val Loss: 8.5540
# Epoch 229, Train Loss: 0.8043, Val Loss: 8.5335
# Epoch 230, Train Loss: 0.7569, Val Loss: 8.4615
# Epoch 231, Train Loss: 0.7961, Val Loss: 8.4727
# Epoch 232, Train Loss: 0.8243, Val Loss: 8.4691
# Epoch 233, Train Loss: 0.8128, Val Loss: 8.6041
# Epoch 234, Train Loss: 0.7937, Val Loss: 8.5253
# Epoch 235, Train Loss: 0.8010, Val Loss: 8.6076
# Epoch 236, Train Loss: 0.7519, Val Loss: 8.5966
# Epoch 237, Train Loss: 0.7948, Val Loss: 8.6175
# Epoch 238, Train Loss: 0.7839, Val Loss: 8.6854
# Epoch 239, Train Loss: 0.8178, Val Loss: 8.5981
# Epoch 240, Train Loss: 0.7628, Val Loss: 8.5589
# Epoch 241, Train Loss: 0.7687, Val Loss: 8.5694
# Epoch 242, Train Loss: 0.8270, Val Loss: 8.6134
# Epoch 243, Train Loss: 0.8139, Val Loss: 8.7984
# Epoch 244, Train Loss: 0.7424, Val Loss: 8.6357
# Epoch 245, Train Loss: 0.8039, Val Loss: 8.4304
# Epoch 246, Train Loss: 0.7982, Val Loss: 8.4452
# Epoch 247, Train Loss: 0.7872, Val Loss: 8.5012
# Epoch 248, Train Loss: 0.7717, Val Loss: 8.5237
# Epoch 249, Train Loss: 0.7243, Val Loss: 8.4741
# Epoch 250, Train Loss: 0.7886, Val Loss: 8.4439
# Epoch 251, Train Loss: 0.7523, Val Loss: 8.3354
# Epoch 252, Train Loss: 0.7533, Val Loss: 8.3755
# Epoch 253, Train Loss: 0.7683, Val Loss: 8.4534
# Epoch 254, Train Loss: 0.7440, Val Loss: 8.4408
# Epoch 255, Train Loss: 0.7536, Val Loss: 8.4610
# Epoch 256, Train Loss: 0.7948, Val Loss: 8.6334
# Epoch 257, Train Loss: 0.7916, Val Loss: 8.5595
# Epoch 258, Train Loss: 0.7814, Val Loss: 8.5509
# Epoch 259, Train Loss: 0.7330, Val Loss: 8.5633
# Epoch 260, Train Loss: 0.7560, Val Loss: 8.5560
# Epoch 261, Train Loss: 0.7657, Val Loss: 8.5669
# Epoch 262, Train Loss: 0.7795, Val Loss: 8.5745
# Epoch 263, Train Loss: 0.7979, Val Loss: 8.6110
# Epoch 264, Train Loss: 0.7508, Val Loss: 8.6801
# Epoch 265, Train Loss: 0.7673, Val Loss: 8.5856
# Epoch 266, Train Loss: 0.7923, Val Loss: 8.5311
# Epoch 267, Train Loss: 0.7758, Val Loss: 8.4576
# Epoch 268, Train Loss: 0.7212, Val Loss: 8.5061
# Epoch 269, Train Loss: 0.7727, Val Loss: 8.4909
# Epoch 270, Train Loss: 0.7411, Val Loss: 8.4567
# Epoch 271, Train Loss: 0.7956, Val Loss: 8.4758
# Epoch 272, Train Loss: 0.7492, Val Loss: 8.4949
# Epoch 273, Train Loss: 0.7996, Val Loss: 8.5215
# Epoch 274, Train Loss: 0.7538, Val Loss: 8.6743
# Epoch 275, Train Loss: 0.8072, Val Loss: 8.7445
# Epoch 276, Train Loss: 0.7566, Val Loss: 8.6645
# Epoch 277, Train Loss: 0.7705, Val Loss: 8.6450
# Epoch 278, Train Loss: 0.7455, Val Loss: 8.6334
# Epoch 279, Train Loss: 0.7484, Val Loss: 8.6798
# Epoch 280, Train Loss: 0.7797, Val Loss: 8.7312
# Epoch 281, Train Loss: 0.7558, Val Loss: 8.6223
# Epoch 282, Train Loss: 0.7563, Val Loss: 8.7179
# Epoch 283, Train Loss: 0.7972, Val Loss: 8.7867
# Epoch 284, Train Loss: 0.7744, Val Loss: 9.0053
# Epoch 285, Train Loss: 0.7539, Val Loss: 8.9543
# Epoch 286, Train Loss: 0.7584, Val Loss: 8.9885
# Epoch 287, Train Loss: 0.7545, Val Loss: 8.9655
# Epoch 288, Train Loss: 0.7270, Val Loss: 9.0743
# Epoch 289, Train Loss: 0.7907, Val Loss: 9.0060
# Epoch 290, Train Loss: 0.7766, Val Loss: 8.8338
# Epoch 291, Train Loss: 0.7755, Val Loss: 8.8659
# Epoch 292, Train Loss: 0.7475, Val Loss: 8.8740
# Epoch 293, Train Loss: 0.7607, Val Loss: 8.9083
# Epoch 294, Train Loss: 0.7405, Val Loss: 8.9712
# Epoch 295, Train Loss: 0.7199, Val Loss: 8.9896
# Epoch 296, Train Loss: 0.7390, Val Loss: 8.9351
# Epoch 297, Train Loss: 0.7594, Val Loss: 8.9002
# Epoch 298, Train Loss: 0.8409, Val Loss: 8.9581
# Epoch 299, Train Loss: 0.7719, Val Loss: 8.9936
# Epoch 300, Train Loss: 0.7833, Val Loss: 8.8780
# Epoch 301, Train Loss: 0.7241, Val Loss: 8.9019
# Epoch 302, Train Loss: 0.8138, Val Loss: 8.9370
# Epoch 303, Train Loss: 0.7859, Val Loss: 8.9534
# Epoch 304, Train Loss: 0.7678, Val Loss: 8.9508
# Epoch 305, Train Loss: 0.7521, Val Loss: 8.8650
# Epoch 306, Train Loss: 0.7957, Val Loss: 8.9319
# Epoch 307, Train Loss: 0.7630, Val Loss: 8.9501
# Epoch 308, Train Loss: 0.7742, Val Loss: 9.0045
# Epoch 309, Train Loss: 0.7623, Val Loss: 9.0418
# Epoch 310, Train Loss: 0.7570, Val Loss: 8.9308
# Epoch 311, Train Loss: 0.7939, Val Loss: 8.9410
# Epoch 312, Train Loss: 0.7901, Val Loss: 8.9585
# Epoch 313, Train Loss: 0.8360, Val Loss: 8.8925
# Epoch 314, Train Loss: 0.7536, Val Loss: 8.7508
# Epoch 315, Train Loss: 0.7449, Val Loss: 8.7486
# Epoch 316, Train Loss: 0.7332, Val Loss: 8.8158
# Epoch 317, Train Loss: 0.7575, Val Loss: 8.8697
# Epoch 318, Train Loss: 0.8080, Val Loss: 8.9155
# Epoch 319, Train Loss: 0.7919, Val Loss: 8.9359
# Epoch 320, Train Loss: 0.7520, Val Loss: 8.8129
# Epoch 321, Train Loss: 0.7612, Val Loss: 8.7632
# Epoch 322, Train Loss: 0.7500, Val Loss: 8.8704
# Epoch 323, Train Loss: 0.7447, Val Loss: 8.8226
# Epoch 324, Train Loss: 0.7542, Val Loss: 8.8185
# Epoch 325, Train Loss: 0.7184, Val Loss: 8.8746
# Epoch 326, Train Loss: 0.8175, Val Loss: 8.9134
# Epoch 327, Train Loss: 0.7563, Val Loss: 8.9893
# Epoch 328, Train Loss: 0.8005, Val Loss: 8.8277
# Epoch 329, Train Loss: 0.8010, Val Loss: 8.7975
# Epoch 330, Train Loss: 0.7321, Val Loss: 8.6559
# Epoch 331, Train Loss: 0.7761, Val Loss: 8.6342
# Epoch 332, Train Loss: 0.7766, Val Loss: 8.6061
# Epoch 333, Train Loss: 0.7579, Val Loss: 8.6201
# Epoch 334, Train Loss: 0.7494, Val Loss: 8.6833
# Epoch 335, Train Loss: 0.7590, Val Loss: 8.6388
# Epoch 336, Train Loss: 0.8029, Val Loss: 8.3810
# Epoch 337, Train Loss: 0.7896, Val Loss: 8.3230
# Epoch 338, Train Loss: 0.8019, Val Loss: 8.3464
# Epoch 339, Train Loss: 0.7495, Val Loss: 8.3476
# Epoch 340, Train Loss: 0.7625, Val Loss: 8.3669
# Epoch 341, Train Loss: 0.7767, Val Loss: 8.4743
# Epoch 342, Train Loss: 0.7975, Val Loss: 8.6584
# Epoch 343, Train Loss: 0.7590, Val Loss: 8.7781
# Epoch 344, Train Loss: 0.7169, Val Loss: 8.7941
# Epoch 345, Train Loss: 0.7801, Val Loss: 8.8178
# Epoch 346, Train Loss: 0.7839, Val Loss: 8.7628
# Epoch 347, Train Loss: 0.7617, Val Loss: 8.7016
# Epoch 348, Train Loss: 0.7316, Val Loss: 8.6392
# Epoch 349, Train Loss: 0.7721, Val Loss: 8.7446
# Epoch 350, Train Loss: 0.7477, Val Loss: 8.7422
# Epoch 351, Train Loss: 0.7566, Val Loss: 8.6619
# Epoch 352, Train Loss: 0.7813, Val Loss: 8.6427
# Epoch 353, Train Loss: 0.7575, Val Loss: 8.6034
# Epoch 354, Train Loss: 0.7353, Val Loss: 8.7384
# Epoch 355, Train Loss: 0.7347, Val Loss: 8.8592
# Epoch 356, Train Loss: 0.7334, Val Loss: 9.0786
# Epoch 357, Train Loss: 0.7790, Val Loss: 8.9470
# Epoch 358, Train Loss: 0.7612, Val Loss: 8.8492
# Epoch 359, Train Loss: 0.7304, Val Loss: 8.8271
# Epoch 360, Train Loss: 0.8097, Val Loss: 8.8462
# Epoch 361, Train Loss: 0.7477, Val Loss: 8.8877
# Epoch 362, Train Loss: 0.8121, Val Loss: 8.9394
# Epoch 363, Train Loss: 0.7401, Val Loss: 8.9898
# Epoch 364, Train Loss: 0.7859, Val Loss: 8.9022
# Epoch 365, Train Loss: 0.8655, Val Loss: 8.8077
# Epoch 366, Train Loss: 0.7645, Val Loss: 8.5622
# Epoch 367, Train Loss: 0.7787, Val Loss: 8.6959
# Epoch 368, Train Loss: 0.7578, Val Loss: 8.7417
# Epoch 369, Train Loss: 0.7425, Val Loss: 9.1030
# Epoch 370, Train Loss: 0.7846, Val Loss: 9.0045
# Epoch 371, Train Loss: 0.9137, Val Loss: 9.7464
# Epoch 372, Train Loss: 0.8260, Val Loss: 8.8831
# Epoch 373, Train Loss: 1.1852, Val Loss: 8.7064
# Epoch 374, Train Loss: 1.1656, Val Loss: 8.1871
# Epoch 375, Train Loss: 1.1690, Val Loss: 7.7478
# Epoch 376, Train Loss: 1.2091, Val Loss: 7.5379
# Epoch 377, Train Loss: 0.9873, Val Loss: 7.5153
# Epoch 378, Train Loss: 1.0050, Val Loss: 7.8441
# Epoch 379, Train Loss: 1.0029, Val Loss: 7.9931
# Epoch 380, Train Loss: 0.9961, Val Loss: 7.9783
# Epoch 381, Train Loss: 1.2387, Val Loss: 8.1799
# Epoch 382, Train Loss: 1.0791, Val Loss: 8.3044
# Epoch 383, Train Loss: 0.9818, Val Loss: 8.0465
# Epoch 384, Train Loss: 1.0073, Val Loss: 7.9695
# Epoch 385, Train Loss: 0.9703, Val Loss: 8.4344
# Epoch 386, Train Loss: 1.0046, Val Loss: 8.5512
# Epoch 387, Train Loss: 0.8895, Val Loss: 8.4609
# Epoch 388, Train Loss: 0.9789, Val Loss: 8.1738
# Epoch 389, Train Loss: 0.8936, Val Loss: 8.2987
# Epoch 390, Train Loss: 1.0146, Val Loss: 8.4169
# Epoch 391, Train Loss: 0.9861, Val Loss: 8.4930
# Epoch 392, Train Loss: 0.9041, Val Loss: 8.3669
# Epoch 393, Train Loss: 0.9031, Val Loss: 8.3771
# Epoch 394, Train Loss: 0.8095, Val Loss: 8.5900
# Epoch 395, Train Loss: 0.8346, Val Loss: 8.4354
# Epoch 396, Train Loss: 0.7786, Val Loss: 8.4263
# Epoch 397, Train Loss: 0.8183, Val Loss: 8.5443
# Epoch 398, Train Loss: 0.8266, Val Loss: 8.7773
# Epoch 399, Train Loss: 0.8879, Val Loss: 8.7614
# Epoch 400, Train Loss: 0.8243, Val Loss: 8.4114
# Epoch 401, Train Loss: 0.8619, Val Loss: 8.6007
# Epoch 402, Train Loss: 0.8693, Val Loss: 8.5522
# Epoch 403, Train Loss: 0.8373, Val Loss: 8.5099
# Epoch 404, Train Loss: 0.8187, Val Loss: 8.5606
# Epoch 405, Train Loss: 0.8095, Val Loss: 8.6403
# Epoch 406, Train Loss: 0.7979, Val Loss: 8.7848
# Epoch 407, Train Loss: 0.8042, Val Loss: 8.7819
# Epoch 408, Train Loss: 0.7604, Val Loss: 8.6281
# Epoch 409, Train Loss: 0.7851, Val Loss: 8.7091
# Epoch 410, Train Loss: 0.7457, Val Loss: 8.7647
# Epoch 411, Train Loss: 0.7731, Val Loss: 8.9882
# Epoch 412, Train Loss: 0.8125, Val Loss: 8.9232
# Epoch 413, Train Loss: 0.7732, Val Loss: 9.0325
# Epoch 414, Train Loss: 0.7715, Val Loss: 8.9116
# Epoch 415, Train Loss: 0.7313, Val Loss: 9.0423
# Epoch 416, Train Loss: 0.8235, Val Loss: 8.9064
# Epoch 417, Train Loss: 0.7393, Val Loss: 8.8767
# Epoch 418, Train Loss: 0.8061, Val Loss: 8.8788
# Epoch 419, Train Loss: 0.7677, Val Loss: 8.9525
# Epoch 420, Train Loss: 0.7719, Val Loss: 8.8800
# Epoch 421, Train Loss: 0.7524, Val Loss: 8.8725
# Epoch 422, Train Loss: 0.8255, Val Loss: 9.0116
# Epoch 423, Train Loss: 0.7660, Val Loss: 9.1914
# Epoch 424, Train Loss: 0.7660, Val Loss: 9.2910
# Epoch 425, Train Loss: 0.7411, Val Loss: 9.2432
# Epoch 426, Train Loss: 0.7873, Val Loss: 9.2201
# Epoch 427, Train Loss: 0.7562, Val Loss: 9.1132
# Epoch 428, Train Loss: 0.8162, Val Loss: 9.1708
# Epoch 429, Train Loss: 0.7954, Val Loss: 9.3261
# Epoch 430, Train Loss: 0.7363, Val Loss: 9.2640
# Epoch 431, Train Loss: 0.7871, Val Loss: 9.1803
# Epoch 432, Train Loss: 0.7239, Val Loss: 9.2366
# Epoch 433, Train Loss: 0.7518, Val Loss: 9.3480
# Epoch 434, Train Loss: 0.7552, Val Loss: 9.2917
# Epoch 435, Train Loss: 0.7681, Val Loss: 9.1528
# Epoch 436, Train Loss: 0.7855, Val Loss: 9.1349
# Epoch 437, Train Loss: 0.7649, Val Loss: 9.1195
# Epoch 438, Train Loss: 0.7611, Val Loss: 9.1794
# Epoch 439, Train Loss: 0.8001, Val Loss: 9.2917
# Epoch 440, Train Loss: 0.7584, Val Loss: 9.3530
# Epoch 441, Train Loss: 0.8155, Val Loss: 9.2484
# Epoch 442, Train Loss: 0.7305, Val Loss: 9.2668
# Epoch 443, Train Loss: 0.7839, Val Loss: 9.2430
# Epoch 444, Train Loss: 0.7644, Val Loss: 9.1859
# Epoch 445, Train Loss: 0.7602, Val Loss: 9.0522
# Epoch 446, Train Loss: 0.7258, Val Loss: 9.0408
# Epoch 447, Train Loss: 0.7621, Val Loss: 8.9549
# Epoch 448, Train Loss: 0.8208, Val Loss: 8.9645
# Epoch 449, Train Loss: 0.7761, Val Loss: 9.0651
# Epoch 450, Train Loss: 0.8337, Val Loss: 9.0963
# Epoch 451, Train Loss: 0.7185, Val Loss: 9.1077
# Epoch 452, Train Loss: 0.7642, Val Loss: 9.0772
# Epoch 453, Train Loss: 0.8018, Val Loss: 9.1356
# Epoch 454, Train Loss: 0.7909, Val Loss: 9.2333
# Epoch 455, Train Loss: 0.7308, Val Loss: 9.2305
# Epoch 456, Train Loss: 0.7491, Val Loss: 9.2391
# Epoch 457, Train Loss: 0.8047, Val Loss: 9.3651
# Epoch 458, Train Loss: 0.7546, Val Loss: 9.3768
# Epoch 459, Train Loss: 0.7939, Val Loss: 9.3536
# Epoch 460, Train Loss: 0.7550, Val Loss: 9.2175
# Epoch 461, Train Loss: 0.7338, Val Loss: 9.1725
# Epoch 462, Train Loss: 0.7628, Val Loss: 9.2413
# Epoch 463, Train Loss: 0.7796, Val Loss: 9.3391
# Epoch 464, Train Loss: 0.7391, Val Loss: 9.2733
# Epoch 465, Train Loss: 0.7868, Val Loss: 9.2811
# Epoch 466, Train Loss: 0.8257, Val Loss: 9.2841
# Epoch 467, Train Loss: 0.7015, Val Loss: 9.3165
# Epoch 468, Train Loss: 0.7548, Val Loss: 9.4181
# Epoch 469, Train Loss: 0.8225, Val Loss: 9.4526
# Epoch 470, Train Loss: 0.7123, Val Loss: 9.1749
# Epoch 471, Train Loss: 0.7560, Val Loss: 9.0817
# Epoch 472, Train Loss: 0.7560, Val Loss: 9.0755
# Epoch 473, Train Loss: 0.7975, Val Loss: 9.1928
# Epoch 474, Train Loss: 0.7633, Val Loss: 9.1122
# Epoch 475, Train Loss: 0.7655, Val Loss: 9.1054
# Epoch 476, Train Loss: 0.7720, Val Loss: 9.1325
# Epoch 477, Train Loss: 0.7372, Val Loss: 9.1856
# Epoch 478, Train Loss: 0.7435, Val Loss: 9.2181
# Epoch 479, Train Loss: 0.7877, Val Loss: 9.3004
# Epoch 480, Train Loss: 0.7484, Val Loss: 9.2895
# Epoch 481, Train Loss: 0.7861, Val Loss: 9.3467
# Epoch 482, Train Loss: 0.7639, Val Loss: 9.2830
# Epoch 483, Train Loss: 0.7274, Val Loss: 9.1924
# Epoch 484, Train Loss: 0.7190, Val Loss: 9.1224
# Epoch 485, Train Loss: 0.7612, Val Loss: 9.1378
# Epoch 486, Train Loss: 0.7837, Val Loss: 9.2549
# Epoch 487, Train Loss: 0.7286, Val Loss: 9.2176
# Epoch 488, Train Loss: 0.8015, Val Loss: 9.2378
# Epoch 489, Train Loss: 0.7100, Val Loss: 9.1418
# Epoch 490, Train Loss: 0.7460, Val Loss: 9.1198
# Epoch 491, Train Loss: 0.7582, Val Loss: 9.0752
# Epoch 492, Train Loss: 0.7527, Val Loss: 9.2769
# Epoch 493, Train Loss: 0.7409, Val Loss: 9.1830
# Epoch 494, Train Loss: 0.7643, Val Loss: 9.1602
# Epoch 495, Train Loss: 0.8129, Val Loss: 9.0937
# Epoch 496, Train Loss: 0.7855, Val Loss: 9.2084
# Epoch 497, Train Loss: 0.8362, Val Loss: 9.3198
# Epoch 498, Train Loss: 0.7868, Val Loss: 9.4618
# Epoch 499, Train Loss: 0.7637, Val Loss: 9.6302

# %%
#testing generation

def generate_text(model, seed_text, vocab, tokenizer, next_words=50, temperature=1.0):
   model.eval()
   tokens = tokenizer(seed_text.lower())
   input_ids = torch.tensor([vocab[token] for token in tokens], dtype=torch.long).unsqueeze(0).to(device)


   generated_text = seed_text
   with torch.no_grad():
       for _ in range(next_words):
           output = model(input_ids)
           output = output.squeeze(0)  # Remove the batch dimension
           output = output / temperature
           probabilities = torch.nn.functional.softmax(output, dim=-1)
           next_token_id = torch.multinomial(probabilities, num_samples=1).item()
           next_token = vocab.lookup_token(next_token_id)
           generated_text += ' ' + next_token
           next_input = torch.tensor([[next_token_id]], dtype=torch.long).to(device)
           input_ids = torch.cat((input_ids, next_input), dim=1)


   return generated_text


seed_text = "Nethaji Nirmal is a"
generated_text = generate_text(model, seed_text, vocab, tokenizer, next_words=50, temperature=1.0)
print(generated_text)
# Out:
# Nethaji Nirmal is a contributor on topics like docker . he plays a contributor on topics like pursuing python , and big data science , ” and practical examples . as using python , ” and deployment using python programming , live classes , and practical examples . at guvi , and deploying applications
