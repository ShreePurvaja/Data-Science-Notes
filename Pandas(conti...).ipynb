# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreePurvaja/Data-Science-Notes/blob/main/Pandas(conti...).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04.03.2025

# %%
import pandas as pd
files=pd.read_csv('/content/diabetes.csv')
display(files)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#used to create a new DataFrame
df=pd.DataFrame(files)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
files.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#to find null values count
files.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
          'team': ['CSK', 'MI', 'MI', 'SRH', 'KKR', 'CSK','CSK', 'CSK'],
          'wins': [11, 8, 10, 15, 11, 6, 10, 4],
          'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
ipl = pd.DataFrame(data)
display (ipl)
# Out:
#    year team  wins  losses
# 0  2010  CSK    11       5
# 1  2011   MI     8       8
# 2  2012   MI    10       6
# 3  2011  SRH    15       1
# 4  2012  KKR    11       5
# 5  2010  CSK     6      10
# 6  2011  CSK    10       6
# 7  2012  CSK     4      12

# %%
ipl["team"]
# Out:
# 0    CSK
# 1     MI
# 2     MI
# 3    SRH
# 4    KKR
# 5    CSK
# 6    CSK
# 7    CSK
# Name: team, dtype: object

# %%
ipl[["team","year"]]
# Out:
#   team  year
# 0  CSK  2010
# 1   MI  2011
# 2   MI  2012
# 3  SRH  2011
# 4  KKR  2012
# 5  CSK  2010
# 6  CSK  2011
# 7  CSK  2012

# %%
#histogram - counts the frequency of data
#bins - divides into equal parts
ipl["team"].hist(bins=15)
# Out:
# <Axes: >

# %%
data = {'year': [10, 11, 12, 11, 12, 10, 11, 12],
          'team': ['CSK', 'MI', 'MI', 'SRH', 'KKR', 'CSK','CSK', 'CSK'],
          'wins': [11, 8, 10, 15, 11, 6, 10, 4],
          'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
ip = pd.DataFrame(data)
display (ip)
# Out:
#    year team  wins  losses
# 0    10  CSK    11       5
# 1    11   MI     8       8
# 2    12   MI    10       6
# 3    11  SRH    15       1
# 4    12  KKR    11       5
# 5    10  CSK     6      10
# 6    11  CSK    10       6
# 7    12  CSK     4      12

# %%
#line plot - all data
ip.plot()
# Out:
# <Axes: >

# %%
#line plot - single data
ip["wins"].plot()
# Out:
# <Axes: >

# %%
#piechart - can only be used for numerical data
ipl.plot.pie(y="wins")
# Out:
# <Axes: ylabel='wins'>

# %%
a=list(ipl.columns)
b=list(ipl.shape)   #rows and columns
c=ipl.size          # mupltiplication of rows and colmns
d=list(ipl.dtypes)
print(a)
print(b)
print(c)
print(d)
# Out:
# ['year', 'team', 'wins', 'losses']
# [8, 4]
# 32
# [dtype('int64'), dtype('O'), dtype('int64'), dtype('int64')]

# %%
e=ipl.values #converts into 2d array and giving
print(e)
# Out:
# [[2010 'CSK' 11 5]
#  [2011 'MI' 8 8]
#  [2012 'MI' 10 6]
#  [2011 'SRH' 15 1]
#  [2012 'KKR' 11 5]
#  [2010 'CSK' 6 10]
#  [2011 'CSK' 10 6]
#  [2012 'CSK' 4 12]]

# %%
ipl["team"].value_counts()
# Out:
# team
# CSK    4
# MI     2
# SRH    1
# KKR    1
# Name: count, dtype: int64

# %% [markdown]
# # loc & iloc

# %%
ipl.loc[0:2]
# Out:
#    year team  wins  losses
# 0  2010  CSK    11       5
# 1  2011   MI     8       8
# 2  2012   MI    10       6

# %%
ipl.loc[0:2,["team","wins"]]
# Out:
#   team  wins
# 0  CSK    11
# 1   MI     8
# 2   MI    10

# %%
#iloc - locating with index or integer
ipl.iloc[0:2]
# Out:
#    year team  wins  losses
# 0  2010  CSK    11       5
# 1  2011   MI     8       8

# %%
ipl.iloc[0:2,0:2]
# Out:
#    year team
# 0  2010  CSK
# 1  2011   MI

# %%
ipl.iloc[[0,3],[0,2]]
# Out:
#    year  wins
# 0  2010    11
# 3  2011    15

# %%
a=ipl.query("wins == 4")
print(a)
# Out:
#    year team  wins  losses
# 7  2012  CSK     4      12

# %%
a = ipl[ipl["wins"] == 4]
print(a)
# Out:
#    year team  wins  losses
# 7  2012  CSK     4      12

# %%
b=ipl[(ipl["wins"]==4) | (ipl["team"]=="CSK")] #or condition is used for multiple conditions
print(b)                                       # and condition is used for single condition
# Out:
#    year team  wins  losses
# 0  2010  CSK    11       5
# 5  2010  CSK     6      10
# 6  2011  CSK    10       6
# 7  2012  CSK     4      12

# %%
a=ipl.query('wins>=4  | team=="CSK"')#to extract or perform our own things
display(a)
# Out:
#    year team  wins  losses
# 0  2010  CSK    11       5
# 1  2011   MI     8       8
# 2  2012   MI    10       6
# 3  2011  SRH    15       1
# 4  2012  KKR    11       5
# 5  2010  CSK     6      10
# 6  2011  CSK    10       6
# 7  2012  CSK     4      12

# %%
ipl.to_csv("ipl.csv")

# %%
ipl.drop(columns = "losses",inplace=True)

# %%
display(ipl)
# Out:
#    year team  wins
# 0  2010  CSK    11
# 1  2011   MI     8
# 2  2012   MI    10
# 3  2011  SRH    15
# 4  2012  KKR    11
# 5  2010  CSK     6
# 6  2011  CSK    10
# 7  2012  CSK     4

# %%
ipl.drop(index = 2,inplace = True) #to delete row

# %%
display(ipl)
# Out:
#    year team  wins
# 0  2010  CSK    11
# 1  2011   MI     8
# 3  2011  SRH    15
# 4  2012  KKR    11
# 5  2010  CSK     6
# 6  2011  CSK    10
# 7  2012  CSK     4

# %%
ipl.reset_index()
# Out:
#    index  year team  wins
# 0      0  2010  CSK    11
# 1      1  2011   MI     8
# 2      3  2011  SRH    15
# 3      4  2012  KKR    11
# 4      5  2010  CSK     6
# 5      6  2011  CSK    10
# 6      7  2012  CSK     4
