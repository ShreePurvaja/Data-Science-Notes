# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreePurvaja/Data-Science-Notes/blob/main/Basics_of_Statistics_%26_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10.03.2025

# %%
import pandas as pd
df = pd.read_csv("/content/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df['BloodPressure'].hist(bins=20)
# Out:
# <Axes: >

# %%
# mean,median,mode for bloodpressure

import pandas as pd
from scipy import stats

df = pd.read_csv("/content/diabetes.csv")

# Calculate mean, median, and mode for BloodPressure
mean_bp = df['BloodPressure'].mean()
median_bp = df['BloodPressure'].median()
mode_bp = df['BloodPressure'].mode()[0]  # Extract the mode value

print(f"Mean Blood Pressure: {mean_bp}")
print(f"Median Blood Pressure: {median_bp}")
print(f"Mode Blood Pressure: {mode_bp}")
# Out:
# Mean Blood Pressure: 69.10546875
# Median Blood Pressure: 72.0
# Mode Blood Pressure: 70

# %%
df['Insulin'].hist(bins=20) #right skewed
# Out:
# <Axes: >

# %%
# mean,median,mode for Insulin

import pandas as pd
from scipy import stats

df = pd.read_csv("/content/diabetes.csv")

# Calculate mean, median, and mode for Insulin
mean_bp = df['Insulin'].mean()
median_bp = df['Insulin'].median()
mode_bp = df['Insulin'].mode()[0]  # Extract the mode value

print(f"Mean Insulin: {mean_bp}")
print(f"Median Insulin: {median_bp}")
print(f"Mode Insulin: {mode_bp}")
# Out:
# Mean Insulin: 79.79947916666667
# Median Insulin: 30.5
# Mode Insulin: 0
