# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreePurvaja/Data-Science-Notes/blob/main/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby(df['day']).count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76
# Thur          62   62   62      62    62    62

# %% [markdown]
# # **Count how many are from female**

# %%
df.groupby(['sex']).count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157

# %% [markdown]
# # **Resetting the index**

# %%
df.groupby('day')['tip'].sum().reset_index()
# Out:
#     day     tip
# 0   Fri   51.96
# 1   Sat  260.40
# 2   Sun  247.39
# 3  Thur  171.83

# %% [markdown]
# # **Sorting the values by tips**

# %%
df.groupby('day')['tip'].sum().reset_index().sort_values(by='tip')
# Out:
#     day     tip
# 0   Fri   51.96
# 3  Thur  171.83
# 2   Sun  247.39
# 1   Sat  260.40

# %% [markdown]
# # **Pivot Table**

# %%
df=pd.read_csv("/content/CAR DETAILS FROM CAR DEKHO.csv")
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %% [markdown]
# # **Pass multiple indices**

# %%
pd.pivot_table(df, index=['name','fuel'], values=['year','selling_price', 'km_driven'])  # Example numeric columns
# Out:
#                                              km_driven  selling_price    year
# name                                 fuel
# Ambassador CLASSIC 1500 DSL AC       Diesel    50000.0       120000.0  2005.0
# Ambassador Classic 2000 Dsz          Diesel   120000.0        50000.0  2002.0
# Ambassador Grand 1800 ISZ MPFI PW CL Petrol    50000.0       430000.0  2012.0
# Audi A4 1.8 TFSI                     Petrol    60000.0      1200000.0  2012.0
# Audi A4 2.0 TDI                      Diesel    58000.0      1295000.0  2011.0
# ...                                                ...            ...     ...
# Volkswagen Vento Petrol Highline AT  Petrol    73129.5       284500.0  2011.0
# Volvo V40 D3 R Design                Diesel    21000.0      1975000.0  2018.0
# Volvo XC 90 D5 Inscription BSIV      Diesel    80000.0      4500000.0  2017.0
# Volvo XC60 D3 Kinetic                Diesel   115992.0      1750000.0  2012.0
# ...

# %%
pd.pivot_table(df, index=['fuel'], values=['year','selling_price', 'km_driven'])  # Example numeric columns
# Out:
#              km_driven  selling_price         year
# fuel
# CNG       67234.750000  277174.925000  2013.475000
# Diesel    79630.977706  669094.252206  2013.606595
# Electric  62000.000000  310000.000000  2006.000000
# LPG       89634.782609  167826.043478  2010.130435
# Petrol    52340.079604  344840.137541  2012.595855

# %%
pd.pivot_table(df, index=['transmission'], values=['year','selling_price', 'km_driven'])  # Example numeric columns
# Out:
#                  km_driven  selling_price         year
# transmission
# Automatic     49688.803571   1.408154e+06  2014.877232
# Manual        68118.162898   4.000667e+05  2012.885149

# %%
pd.pivot_table(df, index=['seller_type'], values=['year','selling_price', 'km_driven'])  # Example numeric columns
# Out:
#                      km_driven  selling_price         year
# seller_type
# Dealer            52827.259557  721822.890342  2014.200201
# Individual        71167.556104  424505.419236  2012.665228
# Trustmark Dealer  39202.215686  914950.980392  2015.813725

# %%
pd.pivot_table(df, index=['owner'], values=['year','selling_price', 'km_driven'])  # Example numeric columns
# Out:
#                          km_driven  selling_price         year
# owner
# First Owner           56015.009887  598636.969633  2014.440678
# Fourth & Above Owner  99138.135802  173901.197531  2007.395062
# Second Owner          81783.518987  343891.088608  2010.983725
# Test Drive Car         4155.000000  954293.941176  2019.529412
# Third Owner           99304.506579  269474.003289  2009.338816

# %%
pd.pivot_table(df, index=['fuel','owner','transmission'], values=['year','selling_price', 'km_driven'])  # Example numeric columns
# Out:
#                                                 km_driven  selling_price  \
# fuel     owner                transmission
# CNG      First Owner          Manual         57482.809524   3.728094e+05
#          Fourth & Above Owner Manual         86666.666667   1.083333e+05
#          Second Owner         Manual         76589.357143   1.916429e+05
#          Third Owner          Manual         75000.000000   1.250000e+05
# Diesel   First Owner          Automatic      52280.286432   2.100643e+06
#                               Manual         72316.727801   5.775635e+05
#          Fourth & Above Owner Automatic     110000.000000   4.000000e+05
#                               Manual        128602.696970   2.390908e+05
#          Second Owner         Automatic      78237.581395   1.229744e+06
#                               Manual         94797.636542   3.928742e+05
#          Test Drive Car       Manual          6458.142857   1.056286e+06
# ...

# %%
pd.pivot_table(df, index=['fuel','transmission'], values=['year','selling_price', 'km_driven'],aggfunc=[len,np.mean])
# Out:
# <ipython-input-41-8cb628333ccf>:1: FutureWarning: The provided callable <function mean at 0x7c9fda031da0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(df, index=['fuel','transmission'], values=['year','selling_price', 'km_driven'],aggfunc=[len,np.mean])
#                             len                              mean  \
#                       km_driven selling_price  year     km_driven
# fuel     transmission
# CNG      Manual              40            40    40  67234.750000
# Diesel   Automatic          254           254   254  59943.484252
#          Manual            1899          1899  1899  82264.270669
# Electric Automatic            1             1     1  62000.000000
# LPG      Manual              23            23    23  89634.782609
# Petrol   Automatic          193           193   193  36129.217617
# ...

# %%
pd.pivot_table(df, index=['fuel','transmission'], values=[ 'km_driven'],aggfunc=[np.sum])
# Out:
# <ipython-input-44-b3f15226b2e5>:1: FutureWarning: The provided callable <function sum at 0x7c9fda030cc0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df, index=['fuel','transmission'], values=[ 'km_driven'],aggfunc=[np.sum])
#                              sum
#                        km_driven
# fuel     transmission
# CNG      Manual          2689390
# Diesel   Automatic      15225645
#          Manual        156219850
# Electric Automatic         62000
# LPG      Manual          2061600
# Petrol   Automatic       6972939
#          Manual        104145050

# %%
df['name'].unique()
# Out:
# array(['Maruti 800 AC', 'Maruti Wagon R LXI Minor',
#        'Hyundai Verna 1.6 SX', ..., 'Mahindra Verito 1.5 D6 BSIII',
#        'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV',
#        'Hyundai i20 Magna 1.4 CRDi'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([2007, 2012, 2017, 2014, 2016, 2015, 2018, 2019, 2013, 2011, 2010,
#        2009, 2006, 1996, 2005, 2008, 2004, 1998, 2003, 2002, 2020, 2000,
#        1999, 2001, 1995, 1997, 1992])

# %%
df['fuel'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Fourth & Above Owner',
#        'Third Owner', 'Test Drive Car'], dtype=object)

# %%
pd.pivot_table(df, index=['fuel','owner'], values=['selling_price', 'km_driven'],aggfunc=[np.sum])
# Out:
# <ipython-input-15-879eb89ab9da>:1: FutureWarning: The provided callable <function sum at 0x7e4d73be4cc0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df, index=['fuel','owner'], values=['selling_price', 'km_driven'],aggfunc=[np.sum])
#                                     sum
#                               km_driven selling_price
# fuel     owner
# CNG      First Owner            1207139       7828997
#          Fourth & Above Owner    260000        325000
#          Second Owner           1072251       2683000
#          Third Owner             150000        250000
# Diesel   First Owner           97545434    1113991960
#          Fourth & Above Owner   4353889       8289998
#          Second Owner          51616213     252851975
#          Test Drive Car           45207       7393999
# ...
